# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import pennylane as qml
import numpy as np
import torch.nn.functional as F


# 量子设备
n_qubits = 4
dev = qml.device("default.qubit", wires=n_qubits)

# 定义量子电路
@qml.qnode(dev, interface="torch")
def quantum_circuit(inputs, weights):
    for i in range(n_qubits):
        qml.RY(inputs[i], wires=i)  # 用 RY 门将经典输入编码到量子态
    for i in range(n_qubits - 1):
        qml.CNOT(wires=[i, i+1])
    qml.RY(weights[0], wires=0)
    qml.RY(weights[1], wires=1)
    qml.RY(weights[2], wires=2)
    qml.RY(weights[3], wires=3)
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

# 定义量子层
class QuantumLayer(nn.Module):
    def __init__(self):
        super(QuantumLayer, self).__init__()
        # 可训练量子参数
        self.weights = nn.Parameter(torch.randn(4))

    def forward(self, x):
        # 只使用前4个特征输入量子电路
        x = x[:, :n_qubits]
        # 将量子电路输出转换为 PyTorch 的 Tensor
        quantum_results = [torch.tensor(quantum_circuit(xi, self.weights),  dtype=torch.float32) for xi in x]
        return torch.stack(quantum_results)

# 定义学生模型（结合经典 CNN 和量子层）
class StudentModel(nn.Module):
    def __init__(self):
        super(StudentModel, self).__init__()
        # 简单的 CNN 层
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, n_qubits)  # 为量子层准备输入
        self.quantum_layer = QuantumLayer()
        self.fc3 = nn.Linear(n_qubits, 100)  # CIFAR-100 有100个类别

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # 特征映射到量子层输入
        x = self.quantum_layer(x)
        x = self.fc3(x)  # 最终分类
        return x

# 定义知识蒸馏损失
def distillation_loss(student_output, teacher_output, temperature=3.0):
    soft_teacher_output = nn.functional.softmax(teacher_output / temperature, dim=1)
    soft_student_output = nn.functional.log_softmax(student_output / temperature, dim=1)
    return nn.KLDivLoss(reduction='batchmean')(soft_student_output, soft_teacher_output)

# 数据预处理
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# CIFAR-100 数据集加载
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=2)

# 初始化教师模型 (这里可以使用预训练的 ResNet 或其他模型)
teacher_model = torchvision.models.resnet18(pretrained=True)
teacher_model.fc = nn.Linear(512, 100)  # 修改输出层以适应 CIFAR-100
teacher_model.eval()  # 设置为评估模式

# 初始化学生模型
student_model = StudentModel()
criterion = nn.CrossEntropyLoss()  # 分类损失
optimizer = optim.Adam(student_model.parameters(), lr=0.001)

# 训练学生模型
for epoch in range(10):  # 训练10个epoch
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        # 获取教师模型的输出 (soft target)
        with torch.no_grad():
            teacher_output = teacher_model(inputs)

        # 学生模型前向传播
        optimizer.zero_grad()
        student_output = student_model(inputs)

        # 计算知识蒸馏损失
        loss = distillation_loss(student_output, teacher_output) + criterion(student_output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 100 == 99:    # 每100个小批量输出一次损失
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
            running_loss = 0.0

print('Finished Training')

# 测试学生模型
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = student_model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the student model on the CIFAR-100 test images: {100 * correct / total}%')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /home/yangz2/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yangz2/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [Epoch 1, Batch 100] loss: 4.714
# [Epoch 1, Batch 200] loss: 4.682
# [Epoch 1, Batch 300] loss: 4.661
# [Epoch 1, Batch 400] loss: 4.646
# [Epoch 1, Batch 500] loss: 4.646
# [Epoch 1, Batch 600] loss: 4.639
# [Epoch 1, Batch 700] loss: 4.629
# [Epoch 1, Batch 800] loss: 4.626
# [Epoch 1, Batch 900] loss: 4.624
# [Epoch 1, Batch 1000] loss: 4.620
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 103
#     101 # 学生模型前向传播
#     102 optimizer.zero_grad()
# --> 103 student_output = student_model(inputs)
#     105 # 计算知识蒸馏损失
#     106 loss = distillation_loss(student_output, teacher_output) + criterion(student_output, labels)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[5], line 61, in StudentModel.forward(self, x)
#      59 x = F.relu(self.fc1(x))
#      60 x = self.fc2(x)  # 特征映射到量子层输入
# ---> 61 x = self.quantum_layer(x)
#      62 x = self.fc3(x)  # 最终分类
#      63 return x
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[5], line 39, in QuantumLayer.forward(self, x)
#      37 x = x[:, :n_qubits]
#      38 # 将量子电路输出转换为 PyTorch 的 Tensor
# ---> 39 quantum_results = [torch.tensor(quantum_circuit(xi, self.weights),  dtype=torch.float32) for xi in x]
#      40 return torch.stack(quantum_results)
#
# Cell In[5], line 39, in <listcomp>(.0)
#      37 x = x[:, :n_qubits]
#      38 # 将量子电路输出转换为 PyTorch 的 Tensor
# ---> 39 quantum_results = [torch.tensor(quantum_circuit(xi, self.weights),  dtype=torch.float32) for xi in x]
#      40 return torch.stack(quantum_results)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1020, in QNode.__call__(self, *args, **kwargs)
#    1018 if qml.capture.enabled():
#    1019     return qml.capture.qnode_call(self, *args, **kwargs)
# -> 1020 return self._impl_call(*args, **kwargs)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1002, in QNode._impl_call(self, *args, **kwargs)
#     999     override_shots = kwargs["shots"]
#    1001 # construct the tape
# -> 1002 self.construct(args, kwargs)
#    1004 original_grad_fn = [self.gradient_fn, self.gradient_kwargs, self.device]
#    1005 self._update_gradient_fn(shots=override_shots, tape=self._tape)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/workflow/qnode.py:851, in QNode.construct(self, args, kwargs)
#     849 with pldb_device_manager(self.device):
#     850     with qml.queuing.AnnotatedQueue() as q:
# --> 851         self._qfunc_output = self.func(*args, **kwargs)
#     853 self._tape = QuantumScript.from_queue(q, shots)
#     855 params = self.tape.get_parameters(trainable_only=False)
#
# Cell In[5], line 26, in quantum_circuit(inputs, weights)
#      24 qml.RY(weights[2], wires=2)
#      25 qml.RY(weights[3], wires=3)
# ---> 26 return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
#
# Cell In[5], line 26, in <listcomp>(.0)
#      24 qml.RY(weights[2], wires=2)
#      25 qml.RY(weights[3], wires=3)
# ---> 26 return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/measurements/expval.py:75, in expval(op)
#      68 if isinstance(op, qml.Identity) and len(op.wires) == 0:
#      69     # temporary solution to merge https://github.com/PennyLaneAI/pennylane/pull/5106
#      70     # allow once we have testing and confidence in qml.expval(I())
#      71     raise NotImplementedError(
#      72         "Expectation values of qml.Identity() without wires are currently not allowed."
#      73     )
# ---> 75 return ExpectationMP(obs=op)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/capture/capture_meta.py:89, in CaptureMeta.__call__(cls, *args, **kwargs)
#      85 if enabled():
#      86     # when tracing is enabled, we want to
#      87     # use bind to construct the class if we want class construction to add it to the jaxpr
#      88     return cls._primitive_bind_call(*args, **kwargs)
# ---> 89 return type.__call__(cls, *args, **kwargs)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/measurements/measurements.py:267, in MeasurementProcess.__init__(self, obs, wires, eigvals, id)
#     264     self._eigvals = qml.math.asarray(eigvals)
#     266 # Queue the measurement process
# --> 267 self.queue()
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/measurements/measurements.py:483, in MeasurementProcess.queue(self, context)
#     481 """Append the measurement process to an annotated queue."""
#     482 if self.obs is not None:
# --> 483     context.remove(self.obs)
#     484 context.append(self)
#     486 return self
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/queuing.py:324, in QueuingManager.remove(cls, obj)
#     318 """Remove an object from the queue(s) if it is in the queue(s).
#     319
#     320 Args:
#     321     obj: the object to be removed
#     322 """
#     323 if cls.recording():
# --> 324     cls.active_context().remove(obj)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/queuing.py:381, in AnnotatedQueue.remove(self, obj)
#     379 obj = obj if isinstance(obj, WrappedObj) else WrappedObj(obj)
#     380 if obj in self:
# --> 381     del self[obj]
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/pennylane/queuing.py:184, in WrappedObj.__eq__(self, other)
#     183 def __eq__(self, other):
# --> 184     if not isinstance(other, WrappedObj):
#     185         return False
#     186     return id(self.obj) == id(other.obj)
#
# KeyboardInterrupt:
