# %%
#!/usr/bin/env python
# coding: utf-8

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pickle, os
from avalanche.benchmarks.classic import SplitMNIST
from avalanche.training import Naive
from avalanche.training.plugins import ReplayPlugin
from avalanche.training.plugins import EvaluationPlugin
from avalanche.evaluation.metrics import (
    accuracy_metrics, loss_metrics,
    forgetting_metrics, timing_metrics,
    cpu_usage_metrics, disk_usage_metrics
)
from avalanche.logging import InteractiveLogger

# 设备切到 cuda:2
device = "cuda:2" if torch.cuda.is_available() else "cpu"

# 定义网络（不变）
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, 1, 1)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, 1)
        self.fc1   = nn.Linear(32 * 7 * 7, 128)
        self.fc2   = nn.Linear(128, num_classes)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 32 * 7 * 7)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# 基准
benchmark = SplitMNIST(n_experiences=5, return_task_id=False)

# 模型、优化器、损失
model     = SimpleCNN(10).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# 日志与评估插件（保留你原来的配置）
interactive_logger = InteractiveLogger()
eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True,     epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    cpu_usage_metrics(experience=True),
    forgetting_metrics(experience=True, stream=True),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loggers=[interactive_logger]
)

# ==== 关键修改：使用 Naive + ReplayPlugin 代替 EWC ====
# Experience Replay 插件，最多存 200 张图，batch_size=32
replay_plugin = ReplayPlugin(
    mem_size=200,
    batch_size=32,      # 每个 minibatch 中新样本的数量
    batch_size_mem=32,  # 每个 minibatch 中重放样本的数量
    task_balanced_dataloader=False
)

strategy = Naive(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    train_epochs=20,
    device=device,
    evaluator=eval_plugin,
    plugins=[replay_plugin]
)
# ======================================================

# 训练 & 评估主循环（略微改了路径）
save_dir = "/home/yangz2/code/quantum_cl/results/list_er"
os.makedirs(save_dir, exist_ok=True)

task_accuracies = []
print("Starting ER-based training...")
for experience in benchmark.train_stream:
    print(f"\n--- Training on experience {experience.current_experience} ---")
    strategy.train(experience)

    print(f"--- Evaluating after experience {experience.current_experience} ---")
    results = strategy.eval(benchmark.test_stream)
    task_accuracies.append(results)

    with open(os.path.join(
        save_dir,
        f"splitmnist_ER_cnn_interim_exp_{experience.current_experience}.pkl"
    ), "wb") as f:
        pickle.dump(task_accuracies, f)

with open(os.path.join(save_dir, "splitmnist_ER_cnn_final.pkl"), "wb") as f:
    pickle.dump(task_accuracies, f)

print("✔ ER Training and evaluation completed!")
# Out:
# 2025-06-18 13:32:51.834611: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-18 13:32:51.872944: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-18 13:32:51.882858: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-18 13:32:51.899942: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-18 13:32:53.879154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/compat/__init__.py:42, in tf()
#      41 try:
# ---> 42     from tensorboard.compat import notf  # noqa: F401
#      43 except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/home/yangz2/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       7 import torch.nn.functional as F
#       8 import pickle, os
# ----> 9 from avalanche.benchmarks.classic import SplitMNIST
#      10 from avalanche.training import Naive
#      11 from avalanche.training.plugins import ReplayPlugin
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/__init__.py:1
# ----> 1 from avalanche import benchmarks
#       2 from avalanche import evaluation
#       3 from avalanche import logging
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/benchmarks/__init__.py:13
#      11 from .scenarios import *
#      12 from .scenarios.deprecated.generators import *
# ---> 13 from .classic import *
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/benchmarks/classic/__init__.py:15
#      13 from .clear import *
#      14 from .stream51 import *
# ---> 15 from .ex_model import *
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/benchmarks/classic/ex_model.py:38
#      36 from avalanche.models import LeNet5, SlimResNet18
#      37 from torchvision.transforms import Compose
# ---> 38 from avalanche.evaluation.metrics import TaskAwareAccuracy
#      39 from avalanche.benchmarks import ExModelCLScenario, nc_benchmark
#      40 import copy
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/evaluation/metrics/__init__.py:20
#      18 from .images_samples import *
#      19 from .topk_acc import *
# ---> 20 from .acc_matrix import *
#      21 from .cumulative_accuracies import *
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/evaluation/metrics/acc_matrix.py:7
#       5 from avalanche.evaluation.metric_results import MetricValue, MetricResult
#       6 from avalanche.evaluation.metrics.accuracy import Accuracy
# ----> 7 from avalanche.training.templates import SupervisedTemplate
#      10 class AccuracyMatrixPluginMetric(PluginMetric[float]):
#      11     """
#      12     Class for obtaining an Accuracy Matrix for the evaluation stream
#      13     """
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/training/__init__.py:10
#       1 """
#       2 The :py:mod:`training` module provides a generic continual learning training
#       3 class (:py:class:`BaseTemplate`) and implementations of the most common
#    (...)
#       6 can be easily combined with your own strategy.
#       7 """
#       9 from .regularization import *
# ---> 10 from .supervised import *
#      11 from .storage_policy import *
#      12 from .losses import *
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/training/supervised/__init__.py:6
#       1 """High-level strategies.
#       2
#       3 This module contains
#       4 """
# ----> 6 from .joint_training import *
#       7 from .ar1 import AR1
#       8 from .cumulative import Cumulative
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/training/supervised/joint_training.py:21
#      19 from avalanche.benchmarks.utils.utils import concat_datasets
#      20 from avalanche.core import BasePlugin
# ---> 21 from avalanche.training.plugins.evaluation import (
#      22     EvaluationPlugin,
#      23     default_evaluator,
#      24 )
#      25 from avalanche.training.templates import SupervisedTemplate
#      26 from avalanche.models import DynamicModule
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/training/plugins/__init__.py:3
#       1 from .agem import AGEMPlugin
#       2 from .cwr_star import CWRStarPlugin
# ----> 3 from .evaluation import EvaluationPlugin
#       4 from .ewc import EWCPlugin
#       5 from .gdumb import GDumbPlugin
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/training/plugins/evaluation.py:19
#      17 from avalanche.evaluation.metric_results import MetricValue
#      18 from avalanche.evaluation.metrics import accuracy_metrics, loss_metrics
# ---> 19 from avalanche.logging import InteractiveLogger
#      21 if TYPE_CHECKING:
#      22     from avalanche.evaluation import PluginMetric
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/logging/__init__.py:2
#       1 from .base_logger import *
# ----> 2 from .tensorboard_logger import *
#       3 from .wandb_logger import *
#       4 from .text_logging import *
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/avalanche/logging/tensorboard_logger.py:20
#      18 from PIL.Image import Image
#      19 from torch import Tensor
# ---> 20 from torch.utils.tensorboard import SummaryWriter
#      21 from matplotlib.pyplot import Figure
#      22 from torchvision.transforms.functional import to_tensor
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py:12
#       9 del Version
#      10 del tensorboard
# ---> 12 from .writer import FileWriter, SummaryWriter  # noqa: F401
#      13 from tensorboard.summary.writer.record_writer import RecordWriter  # noqa: F401
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/utils/tensorboard/writer.py:19
#      16 from tensorboard.summary.writer.event_file_writer import EventFileWriter
#      18 from ._convert_np import make_np
# ---> 19 from ._embedding import get_embedding_info, make_mat, make_sprite, make_tsv, write_pbtxt
#      20 from ._onnx_graph import load_onnx_graph
#      21 from ._pytorch_graph import graph
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/torch/utils/tensorboard/_embedding.py:10
#       6 from tensorboard.compat import tf
#       7 from tensorboard.plugins.projector.projector_config_pb2 import EmbeddingInfo
# ---> 10 _HAS_GFILE_JOIN = hasattr(tf.io.gfile, "join")
#      13 def _gfile_join(a, b):
#      14     # The join API is different between tensorboard's TF stub and TF:
#      15     # https://github.com/tensorflow/tensorboard/issues/6080
#      16     # We need to try both because `tf` may point to either the stub or the real TF.
#      17     if _HAS_GFILE_JOIN:
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/lazy.py:65, in lazy_load.<locals>.wrapper.<locals>.LazyModule.__getattr__(self, attr_name)
#      64 def __getattr__(self, attr_name):
# ---> 65     return getattr(load_once(self), attr_name)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/lazy.py:97, in _memoize.<locals>.wrapper(arg)
#      95     with lock:
#      96         if cache.get(arg, nothing) is nothing:
# ---> 97             cache[arg] = f(arg)
#      98 return cache[arg]
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/lazy.py:50, in lazy_load.<locals>.wrapper.<locals>.load_once(self)
#      48 load_once.loading = True
#      49 try:
# ---> 50     module = load_fn()
#      51 finally:
#      52     load_once.loading = False
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorboard/compat/__init__.py:45, in tf()
#      43 except ImportError:
#      44     try:
# ---> 45         import tensorflow
#      47         return tensorflow
#      48     except ImportError:
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/__init__.py:53
#      51 from tensorflow._api.v2 import autograph
#      52 from tensorflow._api.v2 import bitwise
# ---> 53 from tensorflow._api.v2 import compat
#      54 from tensorflow._api.v2 import config
#      55 from tensorflow._api.v2 import data
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/_api/v2/compat/__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py:35
#      33 from tensorflow._api.v2.compat.v1 import debugging
#      34 from tensorflow._api.v2.compat.v1 import distribute
# ---> 35 from tensorflow._api.v2.compat.v1 import distributions
#      36 from tensorflow._api.v2.compat.v1 import dtypes
#      37 from tensorflow._api.v2.compat.v1 import errors
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v1/distributions/__init__.py:8
#       3 """Public API for tf._api.v2.distributions namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.ops.distributions.bernoulli import Bernoulli # line: 31
#       9 from tensorflow.python.ops.distributions.beta import Beta # line: 46
#      10 from tensorflow.python.ops.distributions.categorical import Categorical # line: 58
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/ops/distributions/__init__.py:16
#       1 # Copyright 2023 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Core module for TensorFlow distribution objects and helpers."""
# ---> 16 from tensorflow.python.ops.distributions import distributions
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/ops/distributions/distributions.py:22
#      20 with deprecation.silence():
#      21   from tensorflow.python.ops.distributions.bernoulli import Bernoulli
# ---> 22   from tensorflow.python.ops.distributions.beta import Beta
#      23   from tensorflow.python.ops.distributions.categorical import Categorical
#      24   from tensorflow.python.ops.distributions.dirichlet import Dirichlet
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/ops/distributions/beta.py:350
#     340       return x
#     341     return control_flow_ops.with_dependencies([
#     342         check_ops.assert_positive(x, message="sample must be positive"),
#     343         check_ops.assert_less(
#    (...)
#     346             message="sample must be less than `1`."),
#     347     ], x)
# --> 350 class BetaWithSoftplusConcentration(Beta):
#     351   """Beta with softplus transform of `concentration1` and `concentration0`."""
#     353   @deprecation.deprecated(
#     354       "2019-01-01",
#     355       "Use `tfd.Beta(tf.nn.softplus(concentration1), "
#    (...)
#     362                allow_nan_stats=True,
#     363                name="BetaWithSoftplusConcentration"):
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/ops/distributions/beta.py:358, in BetaWithSoftplusConcentration()
#     350 class BetaWithSoftplusConcentration(Beta):
#     351   """Beta with softplus transform of `concentration1` and `concentration0`."""
#     353   @deprecation.deprecated(
#     354       "2019-01-01",
#     355       "Use `tfd.Beta(tf.nn.softplus(concentration1), "
#     356       "tf.nn.softplus(concentration2))` instead.",
#     357       warn_once=True)
# --> 358   def __init__(self,
#     359                concentration1,
#     360                concentration0,
#     361                validate_args=False,
#     362                allow_nan_stats=True,
#     363                name="BetaWithSoftplusConcentration"):
#     364     parameters = dict(locals())
#     365     with ops.name_scope(name, values=[concentration1,
#     366                                       concentration0]) as name:
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:386, in deprecated.<locals>.deprecated_wrapper(func_or_class)
#     383   return func(*args, **kwargs)
#     385 doc_controls.set_deprecated(new_func)
# --> 386 new_func = tf_decorator.make_decorator(
#     387     func, new_func, 'deprecated',
#     388     _add_deprecated_function_notice_to_docstring(func.__doc__, date,
#     389                                                  instructions))
#     390 new_func.__signature__ = inspect.signature(func)
#     392 if cls is None:
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/util/tf_decorator.py:136, in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#     134 if decorator_name is None:
#     135   decorator_name = inspect.currentframe().f_back.f_code.co_name
# --> 136 decorator = TFDecorator(decorator_name, target, decorator_doc,
#     137                         decorator_argspec)
#     138 setattr(decorator_func, '_tf_decorator', decorator)
#     139 # Objects that are callables (e.g., a functools.partial object) may not have
#     140 # the following attributes.
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/site-packages/tensorflow/python/util/tf_decorator.py:332, in TFDecorator.__init__(self, decorator_name, target, decorator_doc, decorator_argspec)
#     330 elif callable(target):
#     331   try:
# --> 332     self.__signature__ = inspect.signature(target)
#     333   except (TypeError, ValueError):
#     334     # Certain callables such as builtins can not be inspected for signature.
#     335     pass
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/inspect.py:3254, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3252 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3253     """Get a signature object for the passed callable."""
# -> 3254     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3255                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/inspect.py:3002, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    2998 @classmethod
#    2999 def from_callable(cls, obj, *,
#    3000                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3001     """Constructs Signature for the given callable object."""
# -> 3002     return _signature_from_callable(obj, sigcls=cls,
#    3003                                     follow_wrapper_chains=follow_wrapped,
#    3004                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/inspect.py:2463, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2458             return sig.replace(parameters=new_params)
#    2460 if isfunction(obj) or _signature_is_functionlike(obj):
#    2461     # If it's a pure Python function, or an object that is duck type
#    2462     # of a Python function (Cython functions, for instance), then:
# -> 2463     return _signature_from_function(sigcls, obj,
#    2464                                     skip_bound_arg=skip_bound_arg,
#    2465                                     globals=globals, locals=locals, eval_str=eval_str)
#    2467 if _signature_is_builtin(obj):
#    2468     return _signature_from_builtin(sigcls, obj,
#    2469                                    skip_bound_arg=skip_bound_arg)
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/inspect.py:2334, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2332 kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2333 annotation = annotations.get(name, _empty)
# -> 2334 parameters.append(Parameter(name, annotation=annotation,
#    2335                             kind=kind,
#    2336                             default=defaults[offset]))
#    2337 if posonly_left:
#    2338     posonly_left -= 1
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/inspect.py:2639, in Parameter.__init__(self, name, kind, default, annotation)
#    2637 def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2638     try:
# -> 2639         self._kind = _ParameterKind(kind)
#    2640     except ValueError:
#    2641         raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# File ~/anaconda3/envs/quan_cl/lib/python3.10/enum.py:359, in EnumMeta.__call__(cls, value, names, module, qualname, type, start)
#     354     """
#     355     classes/types should always be True.
#     356     """
#     357     return True
# --> 359 def __call__(cls, value, names=None, *, module=None, qualname=None, type=None, start=1):
#     360     """
#     361     Either returns an existing member, or creates a new enum class.
#     362
#    (...)
#     382     `type`, if set, will be mixed in as the first base class.
#     383     """
#     384     if names is None:  # simple value lookup
#
# KeyboardInterrupt:
