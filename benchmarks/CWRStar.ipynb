# %%
import torch
import torch.nn as nn
import torch.optim as optim

from avalanche.benchmarks import SplitMNIST
from avalanche.logging import InteractiveLogger
from avalanche.training import CWRStar

# --------------------
# 1. 定义经典 CNN 模型
# --------------------
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5, padding=2)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=5, padding=2)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 7 * 7, 256)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        return self.fc2(x)

# --------------------
# 2. 构建 SplitMNIST 基准
# --------------------
benchmark = SplitMNIST(
    n_experiences=5,
    return_task_id=False
)

# --------------------
# 3. 实例化模型、优化器与损失
# --------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimpleCNN(num_classes=10).to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
criterion = nn.CrossEntropyLoss()

# --------------------
# 4. 配置 CWR* 策略
# --------------------
# 使用 CWRStar 来实现 class-incremental learning，
# 会为最后一层 fc2 维护 task-specific 权重
strategy = CWRStar(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    cwr_layer_name=None,    # None 表示自动使用模型最后一层
    train_mb_size=32,
    train_epochs=10,
    eval_mb_size=64,
    device=device
)

# 日志设置
logger = InteractiveLogger()
strategy.evaluator.loggers = [logger]

# --------------------
# 5. 持续训练与评估
# --------------------
task_accuracies = []
print("Starting SplitMNIST + CWRStar...\n")
for experience in benchmark.train_stream:
    print(f"--- Training experience {experience.current_experience} ---")
    strategy.train(experience)
    print("Evaluation on all experiences:")
    task_accuracies.append(strategy.eval(benchmark.test_stream))
    

print("Training completed!")
# Out:
# Starting SplitMNIST + CWRStar...
#
# --- Training experience 0 ---
# -- >> Start of training phase << --
# 100%|██████████| 372/372 [00:06<00:00, 60.69it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1320
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9557
# 100%|██████████| 372/372 [00:06<00:00, 59.22it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0031
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9992
# 100%|██████████| 372/372 [00:05<00:00, 65.92it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0016
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9996
# 100%|██████████| 372/372 [00:05<00:00, 72.58it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0006
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9998
# 100%|██████████| 372/372 [00:05<00:00, 68.24it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0004
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 372/372 [00:04<00:00, 90.34it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0004
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 372/372 [00:04<00:00, 81.69it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0002
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 372/372 [00:04<00:00, 75.49it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0001
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 372/372 [00:05<00:00, 72.43it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0001
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 372/372 [00:05<00:00, 69.00it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0001
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Evaluation on all experiences:
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 91.91it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0009
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9995
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 34/34 [00:00<00:00, 72.55it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 12.2964
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 46.32it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 13.2909
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 31/31 [00:00<00:00, 104.14it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 12.0382
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 30/30 [00:00<00:00, 107.09it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 10.1073
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 9.5897
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1989
# --- Training experience 1 ---
# -- >> Start of training phase << --
# 100%|██████████| 407/407 [00:03<00:00, 105.10it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0867
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9748
# 100%|██████████| 407/407 [00:04<00:00, 96.40it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0282
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9939
# 100%|██████████| 407/407 [00:04<00:00, 98.18it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0223
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9949
# 100%|██████████| 407/407 [00:04<00:00, 101.52it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0197
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9951
# 100%|██████████| 407/407 [00:03<00:00, 102.39it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0176
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9958
# 100%|██████████| 407/407 [00:03<00:00, 102.12it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0160
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9961
# 100%|██████████| 407/407 [00:04<00:00, 92.11it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0153
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9959
# 100%|██████████| 407/407 [00:04<00:00, 98.70it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0142
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9962
# 100%|██████████| 407/407 [00:03<00:00, 102.58it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0136
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9960
# 100%|██████████| 407/407 [00:04<00:00, 99.88it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0132
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9962
# -- >> End of training phase << --
# Evaluation on all experiences:
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 95.38it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1190
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9578
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 34/34 [00:00<00:00, 94.56it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.2470
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9154
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 104.11it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 15.2619
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 31/31 [00:00<00:00, 97.10it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 13.0845
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 30/30 [00:00<00:00, 101.94it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 10.6018
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 7.7020
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.3886
# --- Training experience 2 ---
# -- >> Start of training phase << --
# 100%|██████████| 378/378 [00:03<00:00, 102.24it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1345
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9503
# 100%|██████████| 378/378 [00:03<00:00, 97.22it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0706
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9764
# 100%|██████████| 378/378 [00:03<00:00, 98.92it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0627
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9788
# 100%|██████████| 378/378 [00:04<00:00, 92.52it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0556
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9815
# 100%|██████████| 378/378 [00:03<00:00, 103.43it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0502
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9830
# 100%|██████████| 378/378 [00:03<00:00, 104.81it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0469
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9833
# 100%|██████████| 378/378 [00:03<00:00, 109.36it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0470
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9839
# 100%|██████████| 378/378 [00:03<00:00, 102.76it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0413
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9858
# 100%|██████████| 378/378 [00:04<00:00, 94.10it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0404
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9868
# 100%|██████████| 378/378 [00:03<00:00, 94.94it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0388
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9863
# -- >> End of training phase << --
# Evaluation on all experiences:
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 98.04it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1974
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9452
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 34/34 [00:00<00:00, 105.74it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.3369
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.8974
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 82.35it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.7919
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.6558
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 31/31 [00:00<00:00, 47.21it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 13.5087
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 30/30 [00:00<00:00, 111.84it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 11.3633
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.0411
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.5146
# --- Training experience 3 ---
# -- >> Start of training phase << --
# 100%|██████████| 368/368 [00:03<00:00, 104.60it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1052
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9670
# 100%|██████████| 368/368 [00:03<00:00, 100.39it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0404
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9884
# 100%|██████████| 368/368 [00:03<00:00, 103.29it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0331
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9897
# 100%|██████████| 368/368 [00:03<00:00, 100.06it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0289
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9914
# 100%|██████████| 368/368 [00:03<00:00, 101.82it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0263
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9919
# 100%|██████████| 368/368 [00:03<00:00, 100.43it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0238
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9919
# 100%|██████████| 368/368 [00:03<00:00, 101.77it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0235
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9921
# 100%|██████████| 368/368 [00:04<00:00, 89.62it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0220
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9933
# 100%|██████████| 368/368 [00:03<00:00, 99.95it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0206
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9936
# 100%|██████████| 368/368 [00:03<00:00, 102.24it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0201
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9933
# -- >> End of training phase << --
# Evaluation on all experiences:
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 106.50it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2115
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9447
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 34/34 [00:00<00:00, 99.51it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.4362
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.8747
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 106.51it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 1.1908
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.4671
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 31/31 [00:00<00:00, 105.87it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.5320
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.8240
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 30/30 [00:00<00:00, 97.33it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 12.7759
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 2.8750
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.6325
# --- Training experience 4 ---
# -- >> Start of training phase << --
# 100%|██████████| 352/352 [00:03<00:00, 102.79it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1117
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9759
# 100%|██████████| 352/352 [00:03<00:00, 100.09it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0337
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9940
# 100%|██████████| 352/352 [00:03<00:00, 99.84it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0257
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9956
# 100%|██████████| 352/352 [00:03<00:00, 100.25it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0221
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9957
# 100%|██████████| 352/352 [00:03<00:00, 100.26it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0193
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9964
# 100%|██████████| 352/352 [00:03<00:00, 95.74it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0179
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9965
# 100%|██████████| 352/352 [00:03<00:00, 103.18it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0169
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9967
# 100%|██████████| 352/352 [00:03<00:00, 101.81it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0157
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9971
# 100%|██████████| 352/352 [00:03<00:00, 100.24it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0151
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9973
# 100%|██████████| 352/352 [00:03<00:00, 104.48it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0146
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9971
# -- >> End of training phase << --
# Evaluation on all experiences:
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 97.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2651
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9352
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 34/34 [00:00<00:00, 76.74it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.4806
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.8715
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 32/32 [00:00<00:00, 89.09it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 1.3038
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.4284
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 31/31 [00:00<00:00, 89.38it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.8530
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.6858
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 30/30 [00:00<00:00, 107.13it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 0.5153
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.8207
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.6832
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.7489
# Training completed!

# %%
import os
# Define the file path
file_path = "/home/yangz2/code/quantum_cl/results/list/splitminist_CWRStar.pkl"

# Create directories if they don't exist
os.makedirs(os.path.dirname(file_path), exist_ok=True)  # <-- Add this line

# %%
import pickle
# 存储到文件
with open(file_path, "wb") as f:
    pickle.dump([task_accuracies], f)
